# %%
import yfinance as yf

# %%
yf.download("BTC-USD", start="2025-01-01", progress=True, auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2025-01-01   94419.757812   94929.867188   92788.125000   93425.101562
# 2025-01-02   96886.875000   97739.820312   94201.570312   94416.289062
# 2025-01-03   98107.429688   98956.914062   96034.617188   96881.726562
# 2025-01-04   98236.226562   98734.429688   97562.976562   98106.992188
# 2025-01-05   98314.960938   98813.304688   97291.765625   98233.906250
# ...                   ...            ...            ...            ...
# 2025-10-30  108305.546875  111612.351562  106376.687500  110059.195312
# 2025-10-31  109556.164062  111031.820312  108288.273438  108304.414062
# 2025-11-01  110064.015625  110574.898438  109372.953125  109558.625000
# 2025-11-02  110639.625000  111167.312500  109523.453125  110064.429688
# ...

# %%
ticker: str = 'USDT-USD'
df = yf.download(ticker, start="2010-01-01", progress=True, auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df['Open'].plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='Date'>

# %%
df['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ticker = "USDC-USD"
df = yf.download(ticker, start="2010-01-01", progress=True, auto_adjust=True)
df['Open'].plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <Axes: xlabel='Date'>
